# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.arange(-5,5,0.01)
plt.plot(x,-5*x**2+x**4,'b') # potential
plt.plot(x,+10*x-4*x**3,'g') # force on particle
plt.xlim(-2,2)
plt.ylim(-20,20)
plt.grid()
