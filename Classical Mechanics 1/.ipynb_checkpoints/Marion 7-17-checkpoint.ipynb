# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0,7,1000)
g = 9.8
w = 0.5
plt.plot(t,g * 0.5 / w**2 * (np.cosh(w * t) - np.cos(w * t)),'b')
plt.plot(t,9.8 * 0.5 / 0.5**2 * np.cosh(0.5 * t),'r')
